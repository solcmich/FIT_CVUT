# %% [markdown]
# ### Import knihoven a konfigurace

# %%
import os

import cv2
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image, display

from scipy.spatial import distance

# %matplotlib inline
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

# %% [markdown]
# ### Pomocné funkce

# %%
def select_image_points(img, points_cnt = 4):
    """ Opens a new image window, where user can interactively add or remove image points.
    Points are added while holding CTRL key + pressing left mouse button and removed by ALT key + pressing left mouse button.
    The point selection is terminated by pressing the 'q' key.
    
    Parameters
    ----------
    img : ndarray
        Input image where image points are choosen and drawn.
    points_cnt : Optional[int]
        A maximum number of points to choose. A minimum number of points to compute the projective transformation is 4.
    Returns
    -------
    list
        Returns a list of size >= 4 and size <= points_cnt such that each elements represent (x, y) coordinate in input image.
    """
    if points_cnt < 4: 
        raise ValueError('Number of points must be >= 4.')
        
    points = []
    window_name = 'Point selection'
    img_dimensions = img.shape[:2]
    pts_dist_thresh = 0.01 * img_dimensions[1] # Scale drawing elements with image size
    
    def draw_circle(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            if flags == cv2.EVENT_FLAG_ALTKEY + cv2.EVENT_LBUTTONDOWN: 
                for p in points:
                    if distance.euclidean(p, (x, y)) < pts_dist_thresh:
                        points.remove(p)
                        break
            elif flags == cv2.EVENT_FLAG_CTRLKEY + cv2.EVENT_LBUTTONDOWN and len(points) < points_cnt:
                points.append((x, y))           

    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL | cv2.WINDOW_GUI_NORMAL)
    cv2.resizeWindow(window_name, 1080, 720)
    cv2.moveWindow(window_name, 0, 0)
    cv2.setMouseCallback(window_name, draw_circle)
    
    # Drawing section, scale drawing elements with image size
    circle_diam = int(0.003 * img_dimensions[1])
    lbl_offset = int(0.005 * img_dimensions[1])
    lbl_font_scale = (0.001 * img_dimensions[1])
    lbl_thickness = int(0.003 * img_dimensions[1])
    
    while 1:
        drawn_img = img.copy()
        
        for i, p in enumerate(points):
            cv2.circle(drawn_img, p, circle_diam , (0, 0, 255), cv2.FILLED)
            cv2.putText(drawn_img, str(i), (p[0] + circle_diam + lbl_offset, p[1] + circle_diam + lbl_offset),
                        0, lbl_font_scale, (0, 0, 255), lbl_thickness)
            
        cv2.imshow(window_name, drawn_img)
        k = cv2.waitKey(1) & 0xFF
        
        if k == ord('q'):
            break

    cv2.destroyAllWindows()
    
    if len(points) < 4: 
        raise ValueError('Number of choosen points must be >= 4.')
        
    return points

# %%
def show_images(*imgs, window_name='Image preview'):
    """ Opens multiple image previews depending on the length of the input *imgs list.
    The preview is terminated by pressing the 'q' key.
    
    Parameters
    ----------
    *imgs : list
        Multiple input images which have to be shown.
    window_name : Optional[string]
        An optional window name.
    Returns
    -------
    None
    """
    for i, img in enumerate(imgs, 1):
        window_name_id = window_name + ' ' + str(i)
        cv2.namedWindow(window_name_id, cv2.WINDOW_NORMAL | cv2.WINDOW_GUI_NORMAL)
        #cv2.resizeWindow(window_name_id, 1080, 720)
        cv2.moveWindow(window_name_id, 0, 0)

    while 1:
        for i, img in enumerate(imgs, 1):
            cv2.imshow(window_name + ' ' + str(i), img)
            
        k = cv2.waitKey(1) & 0xFF

        if k == ord('q'):
            break

    cv2.destroyAllWindows()

# %% [markdown]
# ## Úkol

# %% [markdown]
# Vzhledem k ohlasům na časovou náročnost prvního úkolu jsem se rozhodl provést experimentální ulehčení. Pokud jste byli na cvičení, tak by vám to tentokrát opravdu nemělo zabrat moc času - pro jistotu už ale neříkám žádné odhady. Za případný feedback a informaci o době trvání budeme rádi!
#
# Výchozím bodem k tomuto úkolu je [toto cvičení](https://gitlab.fit.cvut.cz/bi-svz/bi-svz/blob/master/tutorials/files/5/perspective-measuring-cont.ipynb).

# %% [markdown]
# ### První část - rovnání dokumentu a následná aplikace OCR
# Práce probíhá se souborem `ocr_img.jpg` na kterém se nachází dokument známých rozměrů (papír A4). Dokument je potřeba transformovat na kolmý pohled a následně využít Google Cloud Vision API k automatizovanému přečtení textu pomocí OCR. Za tuto část je možné získat maximálně **3 body** a **až 1 prémiový**.
#
# ![](ocr_img.jpg)

# %% [markdown]
# **1) Načtěte obrázek, zobrazte ho a uložte si pole cílových korespondečních souřadnic rohů dokumentu.**

# %%
image = cv2.imread('ocr_img.jpg')
real_world_pts = np.array([(0, 0), (2100, 0), (2100, 2970), (0, 2970)])

# %% [markdown]
# **2) Pomocí již hotové funkce `select_image_points()` vyberte obrazové souřadnice rohů dokumentu.**
# Souřadnice musí korespondovat pořadím, takže pokud je levý roh první v předchozím poli, musí být první vybrán i v tomto kroku.

# %%
image_pts = np.array(select_image_points(image))

if (len(image_pts) != len(real_world_pts)):
    raise ValueError('Real world points and image points must be the same size.')

print('format: x, y \n', image_pts)
print('format: x, y \n', real_world_pts)
# Out:
# format: x, y
#  [[ 728 1116]
#  [ 151  556]
#  [ 973  115]
#  [1557  451]]
# format: x, y
#  [[   0    0]
#  [2100    0]
#  [2100 2970]
#  [   0 2970]]

# %% [markdown]
# **3) Vypočtěte transformační matici H, vypište její tvar.**

# %%
H, mask = cv2.findHomography(image_pts,real_world_pts )

# %% [markdown]
# **4) Popište rozdíl mezi [`cv2.getPerspectiveTransform()`](https://docs.opencv.org/3.4.1/da/d54/group__imgproc__transform.html#ga8c1ae0e3589a9d77fffc962c49b22043) a [`cv2.findHomography`](https://docs.opencv.org/3.4.1/d9/d0c/group__calib3d.html#ga4abc2ece9fab9398f2e560d53c8c9780).**

# %% [markdown]
# Find homograhy je chytřejší funkce pracující s více body a využívající algoritmus RANSAC. Perspective transform stačí, pokud máme korektní 4 body (rohy).

# %% [markdown]
# **5) Využijte funkci [`cv2.warpPerspective`](https://docs.opencv.org/3.4.1/da/d54/group__imgproc__transform.html#gaf73673a7e8e18ec6963e3774e6a94b87) k vytvoření kolmého pohledu dokumentu, výsledek zobrazte a uložte.**

# %%
image_warped = cv2.warpPerspective(image, H, (4200, 2970))
image_warped = image_warped[0:2970,0:2100]
cv2.imwrite('warped_img.jpg', image_warped)
show_images(image_warped)

# %% [markdown]
# **6) Zprovozněte si účet na Google Cloudu, abyste mohli využívat službu Cloud Vision API.**
#
# K aktivaci využijte fakultní emailový účet a odkaz, který jsem vám zaslal emailem. Službu Vision je pak nutné explicitně aktivovat v nastavení a ve svém lokálním Python prostředí doinstalovat některé závislosti pomocí příkazu `pip install`. Posledním krokem je vytvoření přístupových údaju v Google Cloudu a stažení API klíče (idealně ve formátu JSON). Blizší detaily o zprovoznění naleznete na https://cloud.google.com/vision/docs/.
#
# **API KLÍČ DO REPOZITÁŘE NEPUSHUJTE.** Přidejte si ho třeba do .gitignore.

# %% [markdown]
# **7) Detekujte text na "narovnaném" obraze pomocí níže uvedené funkce, text vypiště a uložte do textového souboru.**

# %%
def ocr_google(img_path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    import os
    
    #api_key = 'My First Project-b2e2d6f57020.json'
    api_key = 'INSERT-API-KEY-HERE'
    assert os.path.exists(api_key), 'There is no API-KEY in your path! You need to contact google to get one.'
    client = vision.ImageAnnotatorClient.from_service_account_json(api_key)
    
    with io.open(img_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)
    response = client.text_detection(image=image)
    annotations = response.text_annotations

    return annotations

# %%
ocr_google('warped_img.jpg')
# Out:
# [locale: "cs"
# description: "Disciplin\303\241rn\303\255 \305\231\303\241d pro studenty \304\214esk\303\251ho vysok\303\251ho u\304\215en\303\255 technick\303\251ho v Praze\n\304\214VUT\nCESKE VYSOKE\nUCENI TECHNICKE\nVPRAZE\nMinisterstvo \305\241kolstv\303\255, ml\303\241de\305\276e a t\304\233lov\303\275chovy registrovalo podle &36 odst. 2 z\303\241kona \304\215 111/1998\nSb.,o vysok\303\275ch \305\241kol\303\241ch a o zm\304\233n\304\233 a dopin\304\233n\303\255 dal\305\241\303\255ch z\303\241kon\305\257 (z\303\241kon o vysok\303\275ch \305\241kol\303\241ch), dne 7\nz\303\241\305\231\303\255 2017 pod \304\215j. MSMT-21850/2017 Disciplin\303\241rn\303\255 \305\231\303\241d pro studenty Cesk\303\251ho vysok\303\251ho u\304\215en\303\255i\ntechnick\303\251ho v Praze\nMgr.Karolina Gondkova\n\305\231editelka odboru vysok\303\275ch \305\241ko!\nDISCIPLIN ARN RAD PRO STUDENTY\n\304\214ESKEHO VYSOK\303\211HO U\304\214EN\303\215 TECHNICKEHO V PRAZE\nClanek 1\nUvodn\303\255 ustanoveni\nTento Disciplin\303\241rn\303\255 \305\231\303\241d pro studenty Cesk\303\251ho vysok\303\251ho u\304\215enf technick\303\251ho v Praze, v souladu se\nz\303\241konem &.111/1998 Sb., o vysok\303\275ch \305\241kol\303\241ch a o zm\304\233n\304\233 a dopin\304\233n\303\255 dal\305\241\303\255ch z\303\241kon\305\257 (z\303\241kon o\nvysok\303\275ch \305\241kol\303\241ch), ve zn\304\233n\303\255 pozd\304\233j\305\241ich p\305\231edpis\305\257, (d\303\241le jen z\303\241kon) upravuje disciplin\303\241rn\303\255f zeni\nv\303\273\304\215i studentum studuj\303\255c\303\255m ve v\305\241ech bakal\303\241\305\231sk\303\275ch, magistersk\303\275ch a doktorsk\303\275ch studjnich\nprogramech a to fakultnich i nefakultnich.\n\304\214l\303\241nek 2\nSankce\n(1) Za zavin\304\233n\303\251 poru\305\241en\303\255 povinnost\303\255 stanoven\303\275ch pr\303\241vnimi p\305\231edpisy nebo vnitinimi p\305\231edpisy\nCVUT a jeho sou\303\241st\303\255 ize studentovi ulo\305\276it n\304\233kterou z n\303\241sleduj\303\255cich sankei\na) napomenut\303\255,\nb) podmine\304\215n\303\251 vylou\304\215en\303\255 ze studia se stanoven\303\255m Ih\303\273ty a podminek k osv\304\233d\304\215ent\ncvylou\304\215en\303\255 ze studia.\nnedbalosti a m\303\251n\304\233 z\303\241vatny\n(2) Disciplin\303\241rn\303\255 p\305\231estupek podle S 64 z\303\241kona sp\303\241chany\ndisciplin\303\241n\303\255 p\305\231estupek Ize projednat bez ulo\305\276en\303\255 sankce\n(3) Od ulo\305\276en\303\255 sankce je t\303\251\305\274 mo\305\276n\303\251 upustit, jestli\305\276e samotne projedn\303\241nt disciplin\303\241mino\np\305\231estupku vede k n\303\241prav\304\233.\n(4)Ph ukt\303\241d\303\241n\303\255 sankci se p\305\231ihlizi k charakteru jedn\303\241nt, j\303\241m2 by\305\202 disciplin\303\241m\303\255 p\305\231estupek spich\303\241n\nk okolnostem, za nich\305\276 k n\304\233mu do\305\241lo, ke zp\305\257sobenym n\303\241sledk\305\257m, k mite zavinent jako\n"
# bounding_poly {
#   vertices {
#     x: 300
#     y: 146
#   }
#   vertices {
#     x: 1776
#     y: 146
#   }
#   vertices {
#     x: 1776
#     y: 2500
#   }
#   vertices {
#     x: 300
#     y: 2500
#   }
# }
# , description: "Disciplin\303\241rn\303\255"
# bounding_poly {
#   vertices {
#     x: 482
#     y: 146
#   }
#   vertices {
#     x: 669
#     y: 146
#   }
#   vertices {
#     x: 669
#     y: 176
#   }
#   vertices {
#     x: 482
#     y: 176
#   }
# }
# , description: "\305\231\303\241d"
# bounding_poly {
#   vertices {
#     x: 675
#     y: 146
#   }
#   vertices {
#     x: 722
#     y: 146
#   }
#   vertices {
#     x: 722
#     y: 172
#   }
#   vertices {
#     x: 675
#     y: 172
#   }
# }
# , description: "pro"
# bounding_poly {
#   vertices {
#     x: 732
#     y: 155
#   }
#   vertices {
#     x: 781
#     y: 155
#   }
#   vertices {
#     x: 781
#     y: 177
#   }
#   vertices {
#     x: 732
#     y: 177
#   }
# }
# , description: "studenty"
# bounding_poly {
#   vertices {
#     x: 791
#     y: 150
#   }
#   vertices {
#     x: 926
#     y: 150
#   }
#   vertices {
#     x: 926
#     y: 180
#   }
#   vertices {
#     x: 791
#     y: 180
#   }
# }
# , description: "\304\214esk\303\251ho"
# bounding_poly {
#   vertices {
#     x: 936
#     y: 146
#   }
#   vertices {
#     x: 1061
#     y: 146
#   }
#   vertices {
#     x: 1061
#     y: 176
#   }
#   vertices {
#     x: 936
#     y: 176
#   }
# }
# , description: "vysok\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1072
#     y: 150
#   }
#   vertices {
#     x: 1211
#     y: 150
#   }
#   vertices {
#     x: 1211
#     y: 181
#   }
#   vertices {
#     x: 1072
#     y: 181
#   }
# }
# , description: "u\304\215en\303\255"
# bounding_poly {
#   vertices {
#     x: 1222
#     y: 149
#   }
#   vertices {
#     x: 1305
#     y: 149
#   }
#   vertices {
#     x: 1305
#     y: 175
#   }
#   vertices {
#     x: 1222
#     y: 175
#   }
# }
# , description: "technick\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1312
#     y: 148
#   }
#   vertices {
#     x: 1494
#     y: 148
#   }
#   vertices {
#     x: 1494
#     y: 175
#   }
#   vertices {
#     x: 1312
#     y: 175
#   }
# }
# , description: "v"
# bounding_poly {
#   vertices {
#     x: 1504
#     y: 157
#   }
#   vertices {
#     x: 1520
#     y: 157
#   }
#   vertices {
#     x: 1520
#     y: 174
#   }
#   vertices {
#     x: 1504
#     y: 174
#   }
# }
# , description: "Praze"
# bounding_poly {
#   vertices {
#     x: 1528
#     y: 150
#   }
#   vertices {
#     x: 1609
#     y: 150
#   }
#   vertices {
#     x: 1609
#     y: 174
#   }
#   vertices {
#     x: 1528
#     y: 174
#   }
# }
# , description: "\304\214VUT"
# bounding_poly {
#   vertices {
#     x: 1548
#     y: 340
#   }
#   vertices {
#     x: 1771
#     y: 351
#   }
#   vertices {
#     x: 1767
#     y: 418
#   }
#   vertices {
#     x: 1545
#     y: 407
#   }
# }
# , description: "CESKE"
# bounding_poly {
#   vertices {
#     x: 1545
#     y: 492
#   }
#   vertices {
#     x: 1622
#     y: 495
#   }
#   vertices {
#     x: 1621
#     y: 516
#   }
#   vertices {
#     x: 1544
#     y: 513
#   }
# }
# , description: "VYSOKE"
# bounding_poly {
#   vertices {
#     x: 1632
#     y: 495
#   }
#   vertices {
#     x: 1728
#     y: 498
#   }
#   vertices {
#     x: 1727
#     y: 517
#   }
#   vertices {
#     x: 1631
#     y: 514
#   }
# }
# , description: "UCENI"
# bounding_poly {
#   vertices {
#     x: 1545
#     y: 521
#   }
#   vertices {
#     x: 1621
#     y: 523
#   }
#   vertices {
#     x: 1621
#     y: 543
#   }
#   vertices {
#     x: 1545
#     y: 541
#   }
# }
# , description: "TECHNICKE"
# bounding_poly {
#   vertices {
#     x: 1631
#     y: 522
#   }
#   vertices {
#     x: 1767
#     y: 525
#   }
#   vertices {
#     x: 1766
#     y: 546
#   }
#   vertices {
#     x: 1631
#     y: 543
#   }
# }
# , description: "VPRAZE"
# bounding_poly {
#   vertices {
#     x: 1544
#     y: 553
#   }
#   vertices {
#     x: 1645
#     y: 555
#   }
#   vertices {
#     x: 1645
#     y: 571
#   }
#   vertices {
#     x: 1544
#     y: 569
#   }
# }
# , description: "Ministerstvo"
# bounding_poly {
#   vertices {
#     x: 316
#     y: 669
#   }
#   vertices {
#     x: 496
#     y: 669
#   }
#   vertices {
#     x: 496
#     y: 695
#   }
#   vertices {
#     x: 316
#     y: 695
#   }
# }
# , description: "\305\241kolstv\303\255,"
# bounding_poly {
#   vertices {
#     x: 505
#     y: 668
#   }
#   vertices {
#     x: 622
#     y: 668
#   }
#   vertices {
#     x: 622
#     y: 707
#   }
#   vertices {
#     x: 505
#     y: 707
#   }
# }
# , description: "ml\303\241de\305\276e"
# bounding_poly {
#   vertices {
#     x: 632
#     y: 668
#   }
#   vertices {
#     x: 758
#     y: 668
#   }
#   vertices {
#     x: 758
#     y: 694
#   }
#   vertices {
#     x: 632
#     y: 694
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 767
#     y: 676
#   }
#   vertices {
#     x: 782
#     y: 676
#   }
#   vertices {
#     x: 782
#     y: 707
#   }
#   vertices {
#     x: 767
#     y: 707
#   }
# }
# , description: "t\304\233lov\303\275chovy"
# bounding_poly {
#   vertices {
#     x: 794
#     y: 668
#   }
#   vertices {
#     x: 970
#     y: 668
#   }
#   vertices {
#     x: 970
#     y: 707
#   }
#   vertices {
#     x: 794
#     y: 707
#   }
# }
# , description: "registrovalo"
# bounding_poly {
#   vertices {
#     x: 979
#     y: 670
#   }
#   vertices {
#     x: 1154
#     y: 670
#   }
#   vertices {
#     x: 1154
#     y: 707
#   }
#   vertices {
#     x: 979
#     y: 707
#   }
# }
# , description: "podle"
# bounding_poly {
#   vertices {
#     x: 1163
#     y: 670
#   }
#   vertices {
#     x: 1247
#     y: 670
#   }
#   vertices {
#     x: 1247
#     y: 707
#   }
#   vertices {
#     x: 1163
#     y: 707
#   }
# }
# , description: "&36"
# bounding_poly {
#   vertices {
#     x: 1255
#     y: 669
#   }
#   vertices {
#     x: 1319
#     y: 669
#   }
#   vertices {
#     x: 1319
#     y: 707
#   }
#   vertices {
#     x: 1255
#     y: 707
#   }
# }
# , description: "odst."
# bounding_poly {
#   vertices {
#     x: 1327
#     y: 670
#   }
#   vertices {
#     x: 1399
#     y: 670
#   }
#   vertices {
#     x: 1399
#     y: 695
#   }
#   vertices {
#     x: 1327
#     y: 695
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 1410
#     y: 670
#   }
#   vertices {
#     x: 1428
#     y: 670
#   }
#   vertices {
#     x: 1428
#     y: 694
#   }
#   vertices {
#     x: 1410
#     y: 694
#   }
# }
# , description: "z\303\241kona"
# bounding_poly {
#   vertices {
#     x: 1436
#     y: 668
#   }
#   vertices {
#     x: 1541
#     y: 668
#   }
#   vertices {
#     x: 1541
#     y: 707
#   }
#   vertices {
#     x: 1436
#     y: 707
#   }
# }
# , description: "\304\215"
# bounding_poly {
#   vertices {
#     x: 1552
#     y: 669
#   }
#   vertices {
#     x: 1573
#     y: 669
#   }
#   vertices {
#     x: 1573
#     y: 695
#   }
#   vertices {
#     x: 1552
#     y: 695
#   }
# }
# , description: "111/1998"
# bounding_poly {
#   vertices {
#     x: 1589
#     y: 672
#   }
#   vertices {
#     x: 1730
#     y: 672
#   }
#   vertices {
#     x: 1730
#     y: 699
#   }
#   vertices {
#     x: 1589
#     y: 699
#   }
# }
# , description: "Sb.,o"
# bounding_poly {
#   vertices {
#     x: 314
#     y: 708
#   }
#   vertices {
#     x: 392
#     y: 708
#   }
#   vertices {
#     x: 392
#     y: 746
#   }
#   vertices {
#     x: 314
#     y: 746
#   }
# }
# , description: "vysok\303\275ch"
# bounding_poly {
#   vertices {
#     x: 404
#     y: 708
#   }
#   vertices {
#     x: 537
#     y: 708
#   }
#   vertices {
#     x: 537
#     y: 739
#   }
#   vertices {
#     x: 404
#     y: 739
#   }
# }
# , description: "\305\241kol\303\241ch"
# bounding_poly {
#   vertices {
#     x: 547
#     y: 707
#   }
#   vertices {
#     x: 658
#     y: 707
#   }
#   vertices {
#     x: 658
#     y: 734
#   }
#   vertices {
#     x: 547
#     y: 734
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 668
#     y: 715
#   }
#   vertices {
#     x: 683
#     y: 715
#   }
#   vertices {
#     x: 683
#     y: 733
#   }
#   vertices {
#     x: 668
#     y: 733
#   }
# }
# , description: "o"
# bounding_poly {
#   vertices {
#     x: 694
#     y: 715
#   }
#   vertices {
#     x: 710
#     y: 715
#   }
#   vertices {
#     x: 710
#     y: 733
#   }
#   vertices {
#     x: 694
#     y: 733
#   }
# }
# , description: "zm\304\233n\304\233"
# bounding_poly {
#   vertices {
#     x: 719
#     y: 707
#   }
#   vertices {
#     x: 820
#     y: 707
#   }
#   vertices {
#     x: 820
#     y: 732
#   }
#   vertices {
#     x: 719
#     y: 732
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 829
#     y: 714
#   }
#   vertices {
#     x: 844
#     y: 714
#   }
#   vertices {
#     x: 844
#     y: 732
#   }
#   vertices {
#     x: 829
#     y: 732
#   }
# }
# , description: "dopin\304\233n\303\255"
# bounding_poly {
#   vertices {
#     x: 855
#     y: 707
#   }
#   vertices {
#     x: 989
#     y: 707
#   }
#   vertices {
#     x: 989
#     y: 746
#   }
#   vertices {
#     x: 855
#     y: 746
#   }
# }
# , description: "dal\305\241\303\255ch"
# bounding_poly {
#   vertices {
#     x: 994
#     y: 707
#   }
#   vertices {
#     x: 1097
#     y: 707
#   }
#   vertices {
#     x: 1097
#     y: 746
#   }
#   vertices {
#     x: 994
#     y: 746
#   }
# }
# , description: "z\303\241kon\305\257"
# bounding_poly {
#   vertices {
#     x: 1106
#     y: 707
#   }
#   vertices {
#     x: 1212
#     y: 707
#   }
#   vertices {
#     x: 1212
#     y: 733
#   }
#   vertices {
#     x: 1106
#     y: 733
#   }
# }
# , description: "(z\303\241kon"
# bounding_poly {
#   vertices {
#     x: 1221
#     y: 705
#   }
#   vertices {
#     x: 1318
#     y: 705
#   }
#   vertices {
#     x: 1318
#     y: 746
#   }
#   vertices {
#     x: 1221
#     y: 746
#   }
# }
# , description: "o"
# bounding_poly {
#   vertices {
#     x: 1329
#     y: 715
#   }
#   vertices {
#     x: 1346
#     y: 715
#   }
#   vertices {
#     x: 1346
#     y: 733
#   }
#   vertices {
#     x: 1329
#     y: 733
#   }
# }
# , description: "vysok\303\275ch"
# bounding_poly {
#   vertices {
#     x: 1357
#     y: 707
#   }
#   vertices {
#     x: 1491
#     y: 707
#   }
#   vertices {
#     x: 1491
#     y: 746
#   }
#   vertices {
#     x: 1357
#     y: 746
#   }
# }
# , description: "\305\241kol\303\241ch),"
# bounding_poly {
#   vertices {
#     x: 1500
#     y: 708
#   }
#   vertices {
#     x: 1633
#     y: 708
#   }
#   vertices {
#     x: 1633
#     y: 746
#   }
#   vertices {
#     x: 1500
#     y: 746
#   }
# }
# , description: "dne"
# bounding_poly {
#   vertices {
#     x: 1644
#     y: 712
#   }
#   vertices {
#     x: 1702
#     y: 712
#   }
#   vertices {
#     x: 1702
#     y: 737
#   }
#   vertices {
#     x: 1644
#     y: 737
#   }
# }
# , description: "7"
# bounding_poly {
#   vertices {
#     x: 1717
#     y: 714
#   }
#   vertices {
#     x: 1725
#     y: 714
#   }
#   vertices {
#     x: 1725
#     y: 736
#   }
#   vertices {
#     x: 1717
#     y: 736
#   }
# }
# , description: "z\303\241\305\231\303\255"
# bounding_poly {
#   vertices {
#     x: 302
#     y: 740
#   }
#   vertices {
#     x: 379
#     y: 740
#   }
#   vertices {
#     x: 379
#     y: 783
#   }
#   vertices {
#     x: 302
#     y: 783
#   }
# }
# , description: "2017"
# bounding_poly {
#   vertices {
#     x: 381
#     y: 740
#   }
#   vertices {
#     x: 445
#     y: 740
#   }
#   vertices {
#     x: 445
#     y: 783
#   }
#   vertices {
#     x: 381
#     y: 783
#   }
# }
# , description: "pod"
# bounding_poly {
#   vertices {
#     x: 458
#     y: 749
#   }
#   vertices {
#     x: 517
#     y: 749
#   }
#   vertices {
#     x: 517
#     y: 777
#   }
#   vertices {
#     x: 458
#     y: 777
#   }
# }
# , description: "\304\215j."
# bounding_poly {
#   vertices {
#     x: 526
#     y: 747
#   }
#   vertices {
#     x: 555
#     y: 747
#   }
#   vertices {
#     x: 555
#     y: 778
#   }
#   vertices {
#     x: 526
#     y: 778
#   }
# }
# , description: "MSMT-21850/2017"
# bounding_poly {
#   vertices {
#     x: 566
#     y: 748
#   }
#   vertices {
#     x: 835
#     y: 748
#   }
#   vertices {
#     x: 835
#     y: 773
#   }
#   vertices {
#     x: 566
#     y: 773
#   }
# }
# , description: "Disciplin\303\241rn\303\255"
# bounding_poly {
#   vertices {
#     x: 837
#     y: 740
#   }
#   vertices {
#     x: 1031
#     y: 740
#   }
#   vertices {
#     x: 1031
#     y: 783
#   }
#   vertices {
#     x: 837
#     y: 783
#   }
# }
# , description: "\305\231\303\241d"
# bounding_poly {
#   vertices {
#     x: 1033
#     y: 740
#   }
#   vertices {
#     x: 1082
#     y: 740
#   }
#   vertices {
#     x: 1082
#     y: 783
#   }
#   vertices {
#     x: 1033
#     y: 783
#   }
# }
# , description: "pro"
# bounding_poly {
#   vertices {
#     x: 1089
#     y: 753
#   }
#   vertices {
#     x: 1138
#     y: 753
#   }
#   vertices {
#     x: 1138
#     y: 776
#   }
#   vertices {
#     x: 1089
#     y: 776
#   }
# }
# , description: "studenty"
# bounding_poly {
#   vertices {
#     x: 1147
#     y: 747
#   }
#   vertices {
#     x: 1280
#     y: 747
#   }
#   vertices {
#     x: 1280
#     y: 777
#   }
#   vertices {
#     x: 1147
#     y: 777
#   }
# }
# , description: "Cesk\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1288
#     y: 742
#   }
#   vertices {
#     x: 1414
#     y: 742
#   }
#   vertices {
#     x: 1414
#     y: 773
#   }
#   vertices {
#     x: 1288
#     y: 773
#   }
# }
# , description: "vysok\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1424
#     y: 745
#   }
#   vertices {
#     x: 1563
#     y: 745
#   }
#   vertices {
#     x: 1563
#     y: 778
#   }
#   vertices {
#     x: 1424
#     y: 778
#   }
# }
# , description: "u\304\215en\303\255i"
# bounding_poly {
#   vertices {
#     x: 1574
#     y: 747
#   }
#   vertices {
#     x: 1662
#     y: 747
#   }
#   vertices {
#     x: 1662
#     y: 774
#   }
#   vertices {
#     x: 1574
#     y: 774
#   }
# }
# , description: "technick\303\251ho"
# bounding_poly {
#   vertices {
#     x: 317
#     y: 785
#   }
#   vertices {
#     x: 499
#     y: 786
#   }
#   vertices {
#     x: 499
#     y: 813
#   }
#   vertices {
#     x: 317
#     y: 812
#   }
# }
# , description: "v"
# bounding_poly {
#   vertices {
#     x: 509
#     y: 793
#   }
#   vertices {
#     x: 525
#     y: 793
#   }
#   vertices {
#     x: 525
#     y: 811
#   }
#   vertices {
#     x: 509
#     y: 811
#   }
# }
# , description: "Praze"
# bounding_poly {
#   vertices {
#     x: 527
#     y: 781
#   }
#   vertices {
#     x: 605
#     y: 781
#   }
#   vertices {
#     x: 605
#     y: 818
#   }
#   vertices {
#     x: 527
#     y: 818
#   }
# }
# , description: "Mgr.Karolina"
# bounding_poly {
#   vertices {
#     x: 801
#     y: 1016
#   }
#   vertices {
#     x: 986
#     y: 1014
#   }
#   vertices {
#     x: 986
#     y: 1046
#   }
#   vertices {
#     x: 801
#     y: 1048
#   }
# }
# , description: "Gondkova"
# bounding_poly {
#   vertices {
#     x: 998
#     y: 1016
#   }
#   vertices {
#     x: 1142
#     y: 1014
#   }
#   vertices {
#     x: 1142
#     y: 1041
#   }
#   vertices {
#     x: 998
#     y: 1043
#   }
# }
# , description: "\305\231editelka"
# bounding_poly {
#   vertices {
#     x: 770
#     y: 1055
#   }
#   vertices {
#     x: 896
#     y: 1055
#   }
#   vertices {
#     x: 896
#     y: 1080
#   }
#   vertices {
#     x: 770
#     y: 1080
#   }
# }
# , description: "odboru"
# bounding_poly {
#   vertices {
#     x: 907
#     y: 1056
#   }
#   vertices {
#     x: 1012
#     y: 1056
#   }
#   vertices {
#     x: 1012
#     y: 1080
#   }
#   vertices {
#     x: 907
#     y: 1080
#   }
# }
# , description: "vysok\303\275ch"
# bounding_poly {
#   vertices {
#     x: 1023
#     y: 1054
#   }
#   vertices {
#     x: 1156
#     y: 1054
#   }
#   vertices {
#     x: 1156
#     y: 1084
#   }
#   vertices {
#     x: 1023
#     y: 1084
#   }
# }
# , description: "\305\241ko!"
# bounding_poly {
#   vertices {
#     x: 1165
#     y: 1054
#   }
#   vertices {
#     x: 1225
#     y: 1054
#   }
#   vertices {
#     x: 1225
#     y: 1080
#   }
#   vertices {
#     x: 1165
#     y: 1080
#   }
# }
# , description: "DISCIPLIN"
# bounding_poly {
#   vertices {
#     x: 431
#     y: 1216
#   }
#   vertices {
#     x: 772
#     y: 1216
#   }
#   vertices {
#     x: 772
#     y: 1271
#   }
#   vertices {
#     x: 431
#     y: 1271
#   }
# }
# , description: "ARN"
# bounding_poly {
#   vertices {
#     x: 795
#     y: 1216
#   }
#   vertices {
#     x: 903
#     y: 1216
#   }
#   vertices {
#     x: 903
#     y: 1271
#   }
#   vertices {
#     x: 795
#     y: 1271
#   }
# }
# , description: "RAD"
# bounding_poly {
#   vertices {
#     x: 979
#     y: 1220
#   }
#   vertices {
#     x: 1086
#     y: 1220
#   }
#   vertices {
#     x: 1086
#     y: 1256
#   }
#   vertices {
#     x: 979
#     y: 1256
#   }
# }
# , description: "PRO"
# bounding_poly {
#   vertices {
#     x: 1139
#     y: 1227
#   }
#   vertices {
#     x: 1246
#     y: 1227
#   }
#   vertices {
#     x: 1246
#     y: 1256
#   }
#   vertices {
#     x: 1139
#     y: 1256
#   }
# }
# , description: "STUDENTY"
# bounding_poly {
#   vertices {
#     x: 1298
#     y: 1227
#   }
#   vertices {
#     x: 1616
#     y: 1227
#   }
#   vertices {
#     x: 1616
#     y: 1258
#   }
#   vertices {
#     x: 1298
#     y: 1258
#   }
# }
# , description: "\304\214ESKEHO"
# bounding_poly {
#   vertices {
#     x: 605
#     y: 1316
#   }
#   vertices {
#     x: 765
#     y: 1316
#   }
#   vertices {
#     x: 765
#     y: 1353
#   }
#   vertices {
#     x: 605
#     y: 1353
#   }
# }
# , description: "VYSOK\303\211HO"
# bounding_poly {
#   vertices {
#     x: 777
#     y: 1313
#   }
#   vertices {
#     x: 966
#     y: 1313
#   }
#   vertices {
#     x: 966
#     y: 1351
#   }
#   vertices {
#     x: 777
#     y: 1351
#   }
# }
# , description: "U\304\214EN\303\215"
# bounding_poly {
#   vertices {
#     x: 980
#     y: 1312
#   }
#   vertices {
#     x: 1088
#     y: 1312
#   }
#   vertices {
#     x: 1088
#     y: 1350
#   }
#   vertices {
#     x: 980
#     y: 1350
#   }
# }
# , description: "TECHNICKEHO"
# bounding_poly {
#   vertices {
#     x: 1096
#     y: 1312
#   }
#   vertices {
#     x: 1340
#     y: 1312
#   }
#   vertices {
#     x: 1340
#     y: 1349
#   }
#   vertices {
#     x: 1096
#     y: 1349
#   }
# }
# , description: "V"
# bounding_poly {
#   vertices {
#     x: 1352
#     y: 1320
#   }
#   vertices {
#     x: 1375
#     y: 1320
#   }
#   vertices {
#     x: 1375
#     y: 1348
#   }
#   vertices {
#     x: 1352
#     y: 1348
#   }
# }
# , description: "PRAZE"
# bounding_poly {
#   vertices {
#     x: 1387
#     y: 1319
#   }
#   vertices {
#     x: 1497
#     y: 1319
#   }
#   vertices {
#     x: 1497
#     y: 1351
#   }
#   vertices {
#     x: 1387
#     y: 1351
#   }
# }
# , description: "Clanek"
# bounding_poly {
#   vertices {
#     x: 982
#     y: 1469
#   }
#   vertices {
#     x: 1078
#     y: 1468
#   }
#   vertices {
#     x: 1078
#     y: 1498
#   }
#   vertices {
#     x: 982
#     y: 1499
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 1092
#     y: 1473
#   }
#   vertices {
#     x: 1100
#     y: 1473
#   }
#   vertices {
#     x: 1100
#     y: 1496
#   }
#   vertices {
#     x: 1092
#     y: 1496
#   }
# }
# , description: "Uvodn\303\255"
# bounding_poly {
#   vertices {
#     x: 905
#     y: 1508
#   }
#   vertices {
#     x: 1010
#     y: 1508
#   }
#   vertices {
#     x: 1010
#     y: 1540
#   }
#   vertices {
#     x: 905
#     y: 1540
#   }
# }
# , description: "ustanoveni"
# bounding_poly {
#   vertices {
#     x: 1019
#     y: 1508
#   }
#   vertices {
#     x: 1184
#     y: 1508
#   }
#   vertices {
#     x: 1184
#     y: 1539
#   }
#   vertices {
#     x: 1019
#     y: 1539
#   }
# }
# , description: "Tento"
# bounding_poly {
#   vertices {
#     x: 314
#     y: 1571
#   }
#   vertices {
#     x: 397
#     y: 1571
#   }
#   vertices {
#     x: 397
#     y: 1610
#   }
#   vertices {
#     x: 314
#     y: 1610
#   }
# }
# , description: "Disciplin\303\241rn\303\255"
# bounding_poly {
#   vertices {
#     x: 412
#     y: 1571
#   }
#   vertices {
#     x: 599
#     y: 1571
#   }
#   vertices {
#     x: 599
#     y: 1603
#   }
#   vertices {
#     x: 412
#     y: 1603
#   }
# }
# , description: "\305\231\303\241d"
# bounding_poly {
#   vertices {
#     x: 611
#     y: 1572
#   }
#   vertices {
#     x: 657
#     y: 1572
#   }
#   vertices {
#     x: 657
#     y: 1599
#   }
#   vertices {
#     x: 611
#     y: 1599
#   }
# }
# , description: "pro"
# bounding_poly {
#   vertices {
#     x: 673
#     y: 1580
#   }
#   vertices {
#     x: 721
#     y: 1580
#   }
#   vertices {
#     x: 721
#     y: 1604
#   }
#   vertices {
#     x: 673
#     y: 1604
#   }
# }
# , description: "studenty"
# bounding_poly {
#   vertices {
#     x: 735
#     y: 1574
#   }
#   vertices {
#     x: 866
#     y: 1574
#   }
#   vertices {
#     x: 866
#     y: 1604
#   }
#   vertices {
#     x: 735
#     y: 1604
#   }
# }
# , description: "Cesk\303\251ho"
# bounding_poly {
#   vertices {
#     x: 881
#     y: 1568
#   }
#   vertices {
#     x: 1005
#     y: 1568
#   }
#   vertices {
#     x: 1005
#     y: 1599
#   }
#   vertices {
#     x: 881
#     y: 1599
#   }
# }
# , description: "vysok\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1008
#     y: 1564
#   }
#   vertices {
#     x: 1154
#     y: 1564
#   }
#   vertices {
#     x: 1154
#     y: 1610
#   }
#   vertices {
#     x: 1008
#     y: 1610
#   }
# }
# , description: "u\304\215enf"
# bounding_poly {
#   vertices {
#     x: 1170
#     y: 1567
#   }
#   vertices {
#     x: 1249
#     y: 1567
#   }
#   vertices {
#     x: 1249
#     y: 1610
#   }
#   vertices {
#     x: 1170
#     y: 1610
#   }
# }
# , description: "technick\303\251ho"
# bounding_poly {
#   vertices {
#     x: 1251
#     y: 1564
#   }
#   vertices {
#     x: 1436
#     y: 1564
#   }
#   vertices {
#     x: 1436
#     y: 1610
#   }
#   vertices {
#     x: 1251
#     y: 1610
#   }
# }
# , description: "v"
# bounding_poly {
#   vertices {
#     x: 1439
#     y: 1564
#   }
#   vertices {
#     x: 1483
#     y: 1564
#   }
#   vertices {
#     x: 1483
#     y: 1610
#   }
#   vertices {
#     x: 1439
#     y: 1610
#   }
# }
# , description: "Praze,"
# bounding_poly {
#   vertices {
#     x: 1481
#     y: 1572
#   }
#   vertices {
#     x: 1570
#     y: 1572
#   }
#   vertices {
#     x: 1570
#     y: 1603
#   }
#   vertices {
#     x: 1481
#     y: 1603
#   }
# }
# , description: "v"
# bounding_poly {
#   vertices {
#     x: 1583
#     y: 1582
#   }
#   vertices {
#     x: 1599
#     y: 1582
#   }
#   vertices {
#     x: 1599
#     y: 1600
#   }
#   vertices {
#     x: 1583
#     y: 1600
#   }
# }
# , description: "souladu"
# bounding_poly {
#   vertices {
#     x: 1608
#     y: 1578
#   }
#   vertices {
#     x: 1728
#     y: 1578
#   }
#   vertices {
#     x: 1728
#     y: 1604
#   }
#   vertices {
#     x: 1608
#     y: 1604
#   }
# }
# , description: "se"
# bounding_poly {
#   vertices {
#     x: 1742
#     y: 1585
#   }
#   vertices {
#     x: 1775
#     y: 1585
#   }
#   vertices {
#     x: 1775
#     y: 1605
#   }
#   vertices {
#     x: 1742
#     y: 1605
#   }
# }
# , description: "z\303\241konem"
# bounding_poly {
#   vertices {
#     x: 314
#     y: 1608
#   }
#   vertices {
#     x: 451
#     y: 1608
#   }
#   vertices {
#     x: 451
#     y: 1649
#   }
#   vertices {
#     x: 314
#     y: 1649
#   }
# }
# , description: "&.111/1998"
# bounding_poly {
#   vertices {
#     x: 470
#     y: 1612
#   }
#   vertices {
#     x: 649
#     y: 1612
#   }
#   vertices {
#     x: 649
#     y: 1640
#   }
#   vertices {
#     x: 470
#     y: 1640
#   }
# }
# , description: "Sb.,"
# bounding_poly {
#   vertices {
#     x: 664
#     y: 1614
#   }
#   vertices {
#     x: 715
#     y: 1614
#   }
#   vertices {
#     x: 715
#     y: 1644
#   }
#   vertices {
#     x: 664
#     y: 1644
#   }
# }
# , description: "o"
# bounding_poly {
#   vertices {
#     x: 730
#     y: 1620
#   }
#   vertices {
#     x: 747
#     y: 1620
#   }
#   vertices {
#     x: 747
#     y: 1639
#   }
#   vertices {
#     x: 730
#     y: 1639
#   }
# }
# , description: "vysok\303\275ch"
# bounding_poly {
#   vertices {
#     x: 763
#     y: 1612
#   }
#   vertices {
#     x: 897
#     y: 1612
#   }
#   vertices {
#     x: 897
#     y: 1645
#   }
#   vertices {
#     x: 763
#     y: 1645
#   }
# }
# , description: "\305\241kol\303\241ch"
# bounding_poly {
#   vertices {
#     x: 914
#     y: 1612
#   }
#   vertices {
#     x: 1025
#     y: 1612
#   }
#   vertices {
#     x: 1025
#     y: 1640
#   }
#   vertices {
#     x: 914
#     y: 1640
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1041
#     y: 1619
#   }
#   vertices {
#     x: 1056
#     y: 1619
#   }
#   vertices {
#     x: 1056
#     y: 1639
#   }
#   vertices {
#     x: 1041
#     y: 1639
#   }
# }
# , description: "o"
# bounding_poly {
#   vertices {
#     x: 1072
#     y: 1619
#   }
#   vertices {
#     x: 1090
#     y: 1619
#   }
#   vertices {
#     x: 1090
#     y: 1639
#   }
#   vertices {
#     x: 1072
#     y: 1639
#   }
# }
# , description: "zm\304\233n\304\233"
# bounding_poly {
#   vertices {
#     x: 1105
#     y: 1609
#   }
#   vertices {
#     x: 1204
#     y: 1609
#   }
#   vertices {
#     x: 1204
#     y: 1638
#   }
#   vertices {
#     x: 1105
#     y: 1638
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1220
#     y: 1617
#   }
#   vertices {
#     x: 1235
#     y: 1617
#   }
#   vertices {
#     x: 1235
#     y: 1636
#   }
#   vertices {
#     x: 1220
#     y: 1636
#   }
# }
# , description: "dopin\304\233n\303\255"
# bounding_poly {
#   vertices {
#     x: 1245
#     y: 1606
#   }
#   vertices {
#     x: 1382
#     y: 1606
#   }
#   vertices {
#     x: 1382
#     y: 1649
#   }
#   vertices {
#     x: 1245
#     y: 1649
#   }
# }
# , description: "dal\305\241\303\255ch"
# bounding_poly {
#   vertices {
#     x: 1385
#     y: 1606
#   }
#   vertices {
#     x: 1500
#     y: 1606
#   }
#   vertices {
#     x: 1500
#     y: 1649
#   }
#   vertices {
#     x: 1385
#     y: 1649
#   }
# }
# , description: "z\303\241kon\305\257"
# bounding_poly {
#   vertices {
#     x: 1518
#     y: 1611
#   }
#   vertices {
#     x: 1627
#     y: 1611
#   }
#   vertices {
#     x: 1627
#     y: 1642
#   }
#   vertices {
#     x: 1518
#     y: 1642
#   }
# }
# , description: "(z\303\241kon"
# bounding_poly {
#   vertices {
#     x: 1642
#     y: 1615
#   }
#   vertices {
#     x: 1742
#     y: 1615
#   }
#   vertices {
#     x: 1742
#     y: 1645
#   }
#   vertices {
#     x: 1642
#     y: 1645
#   }
# }
# , description: "o"
# bounding_poly {
#   vertices {
#     x: 1758
#     y: 1625
#   }
#   vertices {
#     x: 1775
#     y: 1625
#   }
#   vertices {
#     x: 1775
#     y: 1644
#   }
#   vertices {
#     x: 1758
#     y: 1644
#   }
# }
# , description: "vysok\303\275ch"
# bounding_poly {
#   vertices {
#     x: 314
#     y: 1647
#   }
#   vertices {
#     x: 451
#     y: 1647
#   }
#   vertices {
#     x: 451
#     y: 1690
#   }
#   vertices {
#     x: 314
#     y: 1690
#   }
# }
# , description: "\305\241kol\303\241ch),"
# bounding_poly {
#   vertices {
#     x: 465
#     y: 1650
#   }
#   vertices {
#     x: 596
#     y: 1650
#   }
#   vertices {
#     x: 596
#     y: 1683
#   }
#   vertices {
#     x: 465
#     y: 1683
#   }
# }
# , description: "ve"
# bounding_poly {
#   vertices {
#     x: 609
#     y: 1659
#   }
#   vertices {
#     x: 643
#     y: 1659
#   }
#   vertices {
#     x: 643
#     y: 1679
#   }
#   vertices {
#     x: 609
#     y: 1679
#   }
# }
# , description: "zn\304\233n\303\255"
# bounding_poly {
#   vertices {
#     x: 657
#     y: 1652
#   }
#   vertices {
#     x: 740
#     y: 1652
#   }
#   vertices {
#     x: 740
#     y: 1690
#   }
#   vertices {
#     x: 657
#     y: 1690
#   }
# }
# , description: "pozd\304\233j\305\241ich"
# bounding_poly {
#   vertices {
#     x: 752
#     y: 1651
#   }
#   vertices {
#     x: 912
#     y: 1651
#   }
#   vertices {
#     x: 912
#     y: 1684
#   }
#   vertices {
#     x: 752
#     y: 1684
#   }
# }
# , description: "p\305\231edpis\305\257,"
# bounding_poly {
#   vertices {
#     x: 928
#     y: 1651
#   }
#   vertices {
#     x: 1065
#     y: 1651
#   }
#   vertices {
#     x: 1065
#     y: 1690
#   }
#   vertices {
#     x: 928
#     y: 1690
#   }
# }
# , description: "(d\303\241le"
# bounding_poly {
#   vertices {
#     x: 1077
#     y: 1650
#   }
#   vertices {
#     x: 1150
#     y: 1650
#   }
#   vertices {
#     x: 1150
#     y: 1690
#   }
#   vertices {
#     x: 1077
#     y: 1690
#   }
# }
# , description: "jen"
# bounding_poly {
#   vertices {
#     x: 1161
#     y: 1651
#   }
#   vertices {
#     x: 1208
#     y: 1651
#   }
#   vertices {
#     x: 1208
#     y: 1683
#   }
#   vertices {
#     x: 1161
#     y: 1683
#   }
# }
# , description: "z\303\241kon)"
# bounding_poly {
#   vertices {
#     x: 1216
#     y: 1646
#   }
#   vertices {
#     x: 1346
#     y: 1646
#   }
#   vertices {
#     x: 1346
#     y: 1690
#   }
#   vertices {
#     x: 1216
#     y: 1690
#   }
# }
# , description: "upravuje"
# bounding_poly {
#   vertices {
#     x: 1353
#     y: 1650
#   }
#   vertices {
#     x: 1484
#     y: 1650
#   }
#   vertices {
#     x: 1484
#     y: 1690
#   }
#   vertices {
#     x: 1353
#     y: 1690
#   }
# }
# , description: "disciplin\303\241rn\303\255f"
# bounding_poly {
#   vertices {
#     x: 1497
#     y: 1651
#   }
#   vertices {
#     x: 1683
#     y: 1651
#   }
#   vertices {
#     x: 1683
#     y: 1683
#   }
#   vertices {
#     x: 1497
#     y: 1683
#   }
# }
# , description: "zeni"
# bounding_poly {
#   vertices {
#     x: 1695
#     y: 1655
#   }
#   vertices {
#     x: 1776
#     y: 1655
#   }
#   vertices {
#     x: 1776
#     y: 1683
#   }
#   vertices {
#     x: 1695
#     y: 1683
#   }
# }
# , description: "v\303\273\304\215i"
# bounding_poly {
#   vertices {
#     x: 300
#     y: 1684
#   }
#   vertices {
#     x: 387
#     y: 1684
#   }
#   vertices {
#     x: 387
#     y: 1727
#   }
#   vertices {
#     x: 300
#     y: 1727
#   }
# }
# , description: "studentum"
# bounding_poly {
#   vertices {
#     x: 395
#     y: 1691
#   }
#   vertices {
#     x: 562
#     y: 1691
#   }
#   vertices {
#     x: 562
#     y: 1718
#   }
#   vertices {
#     x: 395
#     y: 1718
#   }
# }
# , description: "studuj\303\255c\303\255m"
# bounding_poly {
#   vertices {
#     x: 586
#     y: 1691
#   }
#   vertices {
#     x: 743
#     y: 1691
#   }
#   vertices {
#     x: 743
#     y: 1723
#   }
#   vertices {
#     x: 586
#     y: 1723
#   }
# }
# , description: "ve"
# bounding_poly {
#   vertices {
#     x: 766
#     y: 1699
#   }
#   vertices {
#     x: 799
#     y: 1699
#   }
#   vertices {
#     x: 799
#     y: 1718
#   }
#   vertices {
#     x: 766
#     y: 1718
#   }
# }
# , description: "v\305\241ech"
# bounding_poly {
#   vertices {
#     x: 821
#     y: 1684
#   }
#   vertices {
#     x: 906
#     y: 1684
#   }
#   vertices {
#     x: 906
#     y: 1718
#   }
#   vertices {
#     x: 821
#     y: 1718
#   }
# }
# , description: "bakal\303\241\305\231sk\303\275ch,"
# bounding_poly {
#   vertices {
#     x: 930
#     y: 1690
#   }
#   vertices {
#     x: 1127
#     y: 1690
#   }
#   vertices {
#     x: 1127
#     y: 1722
#   }
#   vertices {
#     x: 930
#     y: 1722
#   }
# }
# , description: "magistersk\303\275ch"
# bounding_poly {
#   vertices {
#     x: 1149
#     y: 1687
#   }
#   vertices {
#     x: 1361
#     y: 1687
#   }
#   vertices {
#     x: 1361
#     y: 1722
#   }
#   vertices {
#     x: 1149
#     y: 1722
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1382
#     y: 1693
#   }
#   vertices {
#     x: 1397
#     y: 1693
#   }
#   vertices {
#     x: 1397
#     y: 1713
#   }
#   vertices {
#     x: 1382
#     y: 1713
#   }
# }
# , description: "doktorsk\303\275ch"
# bounding_poly {
#   vertices {
#     x: 1420
#     y: 1688
#   }
#   vertices {
#     x: 1605
#     y: 1688
#   }
#   vertices {
#     x: 1605
#     y: 1722
#   }
#   vertices {
#     x: 1420
#     y: 1722
#   }
# }
# , description: "studjnich"
# bounding_poly {
#   vertices {
#     x: 1628
#     y: 1695
#   }
#   vertices {
#     x: 1774
#     y: 1695
#   }
#   vertices {
#     x: 1774
#     y: 1726
#   }
#   vertices {
#     x: 1628
#     y: 1726
#   }
# }
# , description: "programech"
# bounding_poly {
#   vertices {
#     x: 316
#     y: 1731
#   }
#   vertices {
#     x: 500
#     y: 1731
#   }
#   vertices {
#     x: 500
#     y: 1760
#   }
#   vertices {
#     x: 316
#     y: 1760
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 510
#     y: 1738
#   }
#   vertices {
#     x: 525
#     y: 1738
#   }
#   vertices {
#     x: 525
#     y: 1756
#   }
#   vertices {
#     x: 510
#     y: 1756
#   }
# }
# , description: "to"
# bounding_poly {
#   vertices {
#     x: 536
#     y: 1734
#   }
#   vertices {
#     x: 565
#     y: 1734
#   }
#   vertices {
#     x: 565
#     y: 1757
#   }
#   vertices {
#     x: 536
#     y: 1757
#   }
# }
# , description: "fakultnich"
# bounding_poly {
#   vertices {
#     x: 575
#     y: 1729
#   }
#   vertices {
#     x: 721
#     y: 1729
#   }
#   vertices {
#     x: 721
#     y: 1756
#   }
#   vertices {
#     x: 575
#     y: 1756
#   }
# }
# , description: "i"
# bounding_poly {
#   vertices {
#     x: 732
#     y: 1731
#   }
#   vertices {
#     x: 737
#     y: 1731
#   }
#   vertices {
#     x: 737
#     y: 1756
#   }
#   vertices {
#     x: 732
#     y: 1756
#   }
# }
# , description: "nefakultnich."
# bounding_poly {
#   vertices {
#     x: 748
#     y: 1730
#   }
#   vertices {
#     x: 939
#     y: 1730
#   }
#   vertices {
#     x: 939
#     y: 1757
#   }
#   vertices {
#     x: 748
#     y: 1757
#   }
# }
# , description: "\304\214l\303\241nek"
# bounding_poly {
#   vertices {
#     x: 985
#     y: 1823
#   }
#   vertices {
#     x: 1084
#     y: 1824
#   }
#   vertices {
#     x: 1084
#     y: 1855
#   }
#   vertices {
#     x: 985
#     y: 1854
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 1095
#     y: 1829
#   }
#   vertices {
#     x: 1110
#     y: 1829
#   }
#   vertices {
#     x: 1110
#     y: 1854
#   }
#   vertices {
#     x: 1095
#     y: 1854
#   }
# }
# , description: "Sankce"
# bounding_poly {
#   vertices {
#     x: 994
#     y: 1868
#   }
#   vertices {
#     x: 1099
#     y: 1868
#   }
#   vertices {
#     x: 1099
#     y: 1893
#   }
#   vertices {
#     x: 994
#     y: 1893
#   }
# }
# , description: "(1)"
# bounding_poly {
#   vertices {
#     x: 324
#     y: 1923
#   }
#   vertices {
#     x: 362
#     y: 1923
#   }
#   vertices {
#     x: 362
#     y: 1954
#   }
#   vertices {
#     x: 324
#     y: 1954
#   }
# }
# , description: "Za"
# bounding_poly {
#   vertices {
#     x: 382
#     y: 1924
#   }
#   vertices {
#     x: 414
#     y: 1924
#   }
#   vertices {
#     x: 414
#     y: 1960
#   }
#   vertices {
#     x: 382
#     y: 1960
#   }
# }
# , description: "zavin\304\233n\303\251"
# bounding_poly {
#   vertices {
#     x: 432
#     y: 1923
#   }
#   vertices {
#     x: 567
#     y: 1923
#   }
#   vertices {
#     x: 567
#     y: 1960
#   }
#   vertices {
#     x: 432
#     y: 1960
#   }
# }
# , description: "poru\305\241en\303\255"
# bounding_poly {
#   vertices {
#     x: 586
#     y: 1923
#   }
#   vertices {
#     x: 718
#     y: 1923
#   }
#   vertices {
#     x: 718
#     y: 1953
#   }
#   vertices {
#     x: 586
#     y: 1953
#   }
# }
# , description: "povinnost\303\255"
# bounding_poly {
#   vertices {
#     x: 733
#     y: 1923
#   }
#   vertices {
#     x: 891
#     y: 1923
#   }
#   vertices {
#     x: 891
#     y: 1954
#   }
#   vertices {
#     x: 733
#     y: 1954
#   }
# }
# , description: "stanoven\303\275ch"
# bounding_poly {
#   vertices {
#     x: 906
#     y: 1925
#   }
#   vertices {
#     x: 1095
#     y: 1925
#   }
#   vertices {
#     x: 1095
#     y: 1956
#   }
#   vertices {
#     x: 906
#     y: 1956
#   }
# }
# , description: "pr\303\241vnimi"
# bounding_poly {
#   vertices {
#     x: 1114
#     y: 1924
#   }
#   vertices {
#     x: 1242
#     y: 1924
#   }
#   vertices {
#     x: 1242
#     y: 1955
#   }
#   vertices {
#     x: 1114
#     y: 1955
#   }
# }
# , description: "p\305\231edpisy"
# bounding_poly {
#   vertices {
#     x: 1260
#     y: 1924
#   }
#   vertices {
#     x: 1387
#     y: 1924
#   }
#   vertices {
#     x: 1387
#     y: 1955
#   }
#   vertices {
#     x: 1260
#     y: 1955
#   }
# }
# , description: "nebo"
# bounding_poly {
#   vertices {
#     x: 1404
#     y: 1925
#   }
#   vertices {
#     x: 1476
#     y: 1925
#   }
#   vertices {
#     x: 1476
#     y: 1960
#   }
#   vertices {
#     x: 1404
#     y: 1960
#   }
# }
# , description: "vnitinimi"
# bounding_poly {
#   vertices {
#     x: 1492
#     y: 1919
#   }
#   vertices {
#     x: 1622
#     y: 1919
#   }
#   vertices {
#     x: 1622
#     y: 1945
#   }
#   vertices {
#     x: 1492
#     y: 1945
#   }
# }
# , description: "p\305\231edpisy"
# bounding_poly {
#   vertices {
#     x: 1639
#     y: 1921
#   }
#   vertices {
#     x: 1769
#     y: 1921
#   }
#   vertices {
#     x: 1769
#     y: 1953
#   }
#   vertices {
#     x: 1639
#     y: 1953
#   }
# }
# , description: "CVUT"
# bounding_poly {
#   vertices {
#     x: 382
#     y: 1957
#   }
#   vertices {
#     x: 456
#     y: 1957
#   }
#   vertices {
#     x: 456
#     y: 1987
#   }
#   vertices {
#     x: 382
#     y: 1987
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 467
#     y: 1968
#   }
#   vertices {
#     x: 482
#     y: 1968
#   }
#   vertices {
#     x: 482
#     y: 1987
#   }
#   vertices {
#     x: 467
#     y: 1987
#   }
# }
# , description: "jeho"
# bounding_poly {
#   vertices {
#     x: 491
#     y: 1962
#   }
#   vertices {
#     x: 558
#     y: 1962
#   }
#   vertices {
#     x: 558
#     y: 1992
#   }
#   vertices {
#     x: 491
#     y: 1992
#   }
# }
# , description: "sou\303\241st\303\255"
# bounding_poly {
#   vertices {
#     x: 568
#     y: 1961
#   }
#   vertices {
#     x: 693
#     y: 1961
#   }
#   vertices {
#     x: 693
#     y: 1988
#   }
#   vertices {
#     x: 568
#     y: 1988
#   }
# }
# , description: "ize"
# bounding_poly {
#   vertices {
#     x: 702
#     y: 1964
#   }
#   vertices {
#     x: 742
#     y: 1964
#   }
#   vertices {
#     x: 742
#     y: 1988
#   }
#   vertices {
#     x: 702
#     y: 1988
#   }
# }
# , description: "studentovi"
# bounding_poly {
#   vertices {
#     x: 753
#     y: 1963
#   }
#   vertices {
#     x: 912
#     y: 1963
#   }
#   vertices {
#     x: 912
#     y: 1989
#   }
#   vertices {
#     x: 753
#     y: 1989
#   }
# }
# , description: "ulo\305\276it"
# bounding_poly {
#   vertices {
#     x: 923
#     y: 1963
#   }
#   vertices {
#     x: 1003
#     y: 1963
#   }
#   vertices {
#     x: 1003
#     y: 1990
#   }
#   vertices {
#     x: 923
#     y: 1990
#   }
# }
# , description: "n\304\233kterou"
# bounding_poly {
#   vertices {
#     x: 1015
#     y: 1956
#   }
#   vertices {
#     x: 1147
#     y: 1956
#   }
#   vertices {
#     x: 1147
#     y: 1990
#   }
#   vertices {
#     x: 1015
#     y: 1990
#   }
# }
# , description: "z"
# bounding_poly {
#   vertices {
#     x: 1157
#     y: 1970
#   }
#   vertices {
#     x: 1171
#     y: 1970
#   }
#   vertices {
#     x: 1171
#     y: 1989
#   }
#   vertices {
#     x: 1157
#     y: 1989
#   }
# }
# , description: "n\303\241sleduj\303\255cich"
# bounding_poly {
#   vertices {
#     x: 1181
#     y: 1962
#   }
#   vertices {
#     x: 1374
#     y: 1962
#   }
#   vertices {
#     x: 1374
#     y: 1994
#   }
#   vertices {
#     x: 1181
#     y: 1994
#   }
# }
# , description: "sankei"
# bounding_poly {
#   vertices {
#     x: 1384
#     y: 1960
#   }
#   vertices {
#     x: 1475
#     y: 1960
#   }
#   vertices {
#     x: 1475
#     y: 1988
#   }
#   vertices {
#     x: 1384
#     y: 1988
#   }
# }
# , description: "a)"
# bounding_poly {
#   vertices {
#     x: 405
#     y: 2016
#   }
#   vertices {
#     x: 430
#     y: 2016
#   }
#   vertices {
#     x: 430
#     y: 2045
#   }
#   vertices {
#     x: 405
#     y: 2045
#   }
# }
# , description: "napomenut\303\255,"
# bounding_poly {
#   vertices {
#     x: 451
#     y: 2018
#   }
#   vertices {
#     x: 641
#     y: 2019
#   }
#   vertices {
#     x: 641
#     y: 2049
#   }
#   vertices {
#     x: 451
#     y: 2048
#   }
# }
# , description: "b)"
# bounding_poly {
#   vertices {
#     x: 404
#     y: 2074
#   }
#   vertices {
#     x: 433
#     y: 2074
#   }
#   vertices {
#     x: 433
#     y: 2105
#   }
#   vertices {
#     x: 404
#     y: 2105
#   }
# }
# , description: "podmine\304\215n\303\251"
# bounding_poly {
#   vertices {
#     x: 450
#     y: 2075
#   }
#   vertices {
#     x: 639
#     y: 2075
#   }
#   vertices {
#     x: 639
#     y: 2106
#   }
#   vertices {
#     x: 450
#     y: 2106
#   }
# }
# , description: "vylou\304\215en\303\255"
# bounding_poly {
#   vertices {
#     x: 649
#     y: 2078
#   }
#   vertices {
#     x: 793
#     y: 2078
#   }
#   vertices {
#     x: 793
#     y: 2109
#   }
#   vertices {
#     x: 649
#     y: 2109
#   }
# }
# , description: "ze"
# bounding_poly {
#   vertices {
#     x: 801
#     y: 2085
#   }
#   vertices {
#     x: 834
#     y: 2085
#   }
#   vertices {
#     x: 834
#     y: 2105
#   }
#   vertices {
#     x: 801
#     y: 2105
#   }
# }
# , description: "studia"
# bounding_poly {
#   vertices {
#     x: 845
#     y: 2080
#   }
#   vertices {
#     x: 935
#     y: 2080
#   }
#   vertices {
#     x: 935
#     y: 2105
#   }
#   vertices {
#     x: 845
#     y: 2105
#   }
# }
# , description: "se"
# bounding_poly {
#   vertices {
#     x: 946
#     y: 2086
#   }
#   vertices {
#     x: 978
#     y: 2086
#   }
#   vertices {
#     x: 978
#     y: 2106
#   }
#   vertices {
#     x: 946
#     y: 2106
#   }
# }
# , description: "stanoven\303\255m"
# bounding_poly {
#   vertices {
#     x: 989
#     y: 2081
#   }
#   vertices {
#     x: 1163
#     y: 2081
#   }
#   vertices {
#     x: 1163
#     y: 2107
#   }
#   vertices {
#     x: 989
#     y: 2107
#   }
# }
# , description: "Ih\303\273ty"
# bounding_poly {
#   vertices {
#     x: 1173
#     y: 2079
#   }
#   vertices {
#     x: 1246
#     y: 2079
#   }
#   vertices {
#     x: 1246
#     y: 2110
#   }
#   vertices {
#     x: 1173
#     y: 2110
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1255
#     y: 2086
#   }
#   vertices {
#     x: 1270
#     y: 2086
#   }
#   vertices {
#     x: 1270
#     y: 2104
#   }
#   vertices {
#     x: 1255
#     y: 2104
#   }
# }
# , description: "podminek"
# bounding_poly {
#   vertices {
#     x: 1281
#     y: 2077
#   }
#   vertices {
#     x: 1427
#     y: 2077
#   }
#   vertices {
#     x: 1427
#     y: 2108
#   }
#   vertices {
#     x: 1281
#     y: 2108
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 1437
#     y: 2077
#   }
#   vertices {
#     x: 1451
#     y: 2077
#   }
#   vertices {
#     x: 1451
#     y: 2099
#   }
#   vertices {
#     x: 1437
#     y: 2099
#   }
# }
# , description: "osv\304\233d\304\215ent"
# bounding_poly {
#   vertices {
#     x: 1461
#     y: 2071
#   }
#   vertices {
#     x: 1615
#     y: 2071
#   }
#   vertices {
#     x: 1615
#     y: 2103
#   }
#   vertices {
#     x: 1461
#     y: 2103
#   }
# }
# , description: "cvylou\304\215en\303\255"
# bounding_poly {
#   vertices {
#     x: 397
#     y: 2127
#   }
#   vertices {
#     x: 595
#     y: 2127
#   }
#   vertices {
#     x: 595
#     y: 2170
#   }
#   vertices {
#     x: 397
#     y: 2170
#   }
# }
# , description: "ze"
# bounding_poly {
#   vertices {
#     x: 597
#     y: 2127
#   }
#   vertices {
#     x: 632
#     y: 2127
#   }
#   vertices {
#     x: 632
#     y: 2170
#   }
#   vertices {
#     x: 597
#     y: 2170
#   }
# }
# , description: "studia."
# bounding_poly {
#   vertices {
#     x: 644
#     y: 2137
#   }
#   vertices {
#     x: 743
#     y: 2137
#   }
#   vertices {
#     x: 743
#     y: 2162
#   }
#   vertices {
#     x: 644
#     y: 2162
#   }
# }
# , description: "nedbalosti"
# bounding_poly {
#   vertices {
#     x: 1330
#     y: 2229
#   }
#   vertices {
#     x: 1483
#     y: 2229
#   }
#   vertices {
#     x: 1483
#     y: 2255
#   }
#   vertices {
#     x: 1330
#     y: 2255
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1497
#     y: 2221
#   }
#   vertices {
#     x: 1520
#     y: 2221
#   }
#   vertices {
#     x: 1520
#     y: 2271
#   }
#   vertices {
#     x: 1497
#     y: 2271
#   }
# }
# , description: "m\303\251n\304\233"
# bounding_poly {
#   vertices {
#     x: 1523
#     y: 2221
#   }
#   vertices {
#     x: 1630
#     y: 2221
#   }
#   vertices {
#     x: 1630
#     y: 2271
#   }
#   vertices {
#     x: 1523
#     y: 2271
#   }
# }
# , description: "z\303\241vatny"
# bounding_poly {
#   vertices {
#     x: 1648
#     y: 2227
#   }
#   vertices {
#     x: 1764
#     y: 2227
#   }
#   vertices {
#     x: 1764
#     y: 2257
#   }
#   vertices {
#     x: 1648
#     y: 2257
#   }
# }
# , description: "(2)"
# bounding_poly {
#   vertices {
#     x: 322
#     y: 2230
#   }
#   vertices {
#     x: 359
#     y: 2230
#   }
#   vertices {
#     x: 359
#     y: 2261
#   }
#   vertices {
#     x: 322
#     y: 2261
#   }
# }
# , description: "Disciplin\303\241rn\303\255"
# bounding_poly {
#   vertices {
#     x: 382
#     y: 2231
#   }
#   vertices {
#     x: 563
#     y: 2231
#   }
#   vertices {
#     x: 563
#     y: 2271
#   }
#   vertices {
#     x: 382
#     y: 2271
#   }
# }
# , description: "p\305\231estupek"
# bounding_poly {
#   vertices {
#     x: 591
#     y: 2231
#   }
#   vertices {
#     x: 741
#     y: 2231
#   }
#   vertices {
#     x: 741
#     y: 2271
#   }
#   vertices {
#     x: 591
#     y: 2271
#   }
# }
# , description: "podle"
# bounding_poly {
#   vertices {
#     x: 770
#     y: 2234
#   }
#   vertices {
#     x: 853
#     y: 2234
#   }
#   vertices {
#     x: 853
#     y: 2262
#   }
#   vertices {
#     x: 770
#     y: 2262
#   }
# }
# , description: "S"
# bounding_poly {
#   vertices {
#     x: 882
#     y: 2234
#   }
#   vertices {
#     x: 900
#     y: 2234
#   }
#   vertices {
#     x: 900
#     y: 2264
#   }
#   vertices {
#     x: 882
#     y: 2264
#   }
# }
# , description: "64"
# bounding_poly {
#   vertices {
#     x: 928
#     y: 2236
#   }
#   vertices {
#     x: 961
#     y: 2236
#   }
#   vertices {
#     x: 961
#     y: 2260
#   }
#   vertices {
#     x: 928
#     y: 2260
#   }
# }
# , description: "z\303\241kona"
# bounding_poly {
#   vertices {
#     x: 990
#     y: 2235
#   }
#   vertices {
#     x: 1094
#     y: 2235
#   }
#   vertices {
#     x: 1094
#     y: 2262
#   }
#   vertices {
#     x: 990
#     y: 2262
#   }
# }
# , description: "sp\303\241chany"
# bounding_poly {
#   vertices {
#     x: 1123
#     y: 2232
#   }
#   vertices {
#     x: 1261
#     y: 2232
#   }
#   vertices {
#     x: 1261
#     y: 2266
#   }
#   vertices {
#     x: 1123
#     y: 2266
#   }
# }
# , description: "disciplin\303\241n\303\255"
# bounding_poly {
#   vertices {
#     x: 381
#     y: 2269
#   }
#   vertices {
#     x: 561
#     y: 2270
#   }
#   vertices {
#     x: 561
#     y: 2301
#   }
#   vertices {
#     x: 381
#     y: 2300
#   }
# }
# , description: "p\305\231estupek"
# bounding_poly {
#   vertices {
#     x: 571
#     y: 2270
#   }
#   vertices {
#     x: 721
#     y: 2271
#   }
#   vertices {
#     x: 721
#     y: 2302
#   }
#   vertices {
#     x: 571
#     y: 2301
#   }
# }
# , description: "Ize"
# bounding_poly {
#   vertices {
#     x: 732
#     y: 2273
#   }
#   vertices {
#     x: 773
#     y: 2273
#   }
#   vertices {
#     x: 773
#     y: 2297
#   }
#   vertices {
#     x: 732
#     y: 2297
#   }
# }
# , description: "projednat"
# bounding_poly {
#   vertices {
#     x: 784
#     y: 2274
#   }
#   vertices {
#     x: 929
#     y: 2275
#   }
#   vertices {
#     x: 929
#     y: 2303
#   }
#   vertices {
#     x: 784
#     y: 2302
#   }
# }
# , description: "bez"
# bounding_poly {
#   vertices {
#     x: 941
#     y: 2275
#   }
#   vertices {
#     x: 992
#     y: 2275
#   }
#   vertices {
#     x: 992
#     y: 2299
#   }
#   vertices {
#     x: 941
#     y: 2299
#   }
# }
# , description: "ulo\305\276en\303\255"
# bounding_poly {
#   vertices {
#     x: 1003
#     y: 2273
#   }
#   vertices {
#     x: 1111
#     y: 2274
#   }
#   vertices {
#     x: 1111
#     y: 2302
#   }
#   vertices {
#     x: 1003
#     y: 2301
#   }
# }
# , description: "sankce"
# bounding_poly {
#   vertices {
#     x: 1113
#     y: 2267
#   }
#   vertices {
#     x: 1221
#     y: 2268
#   }
#   vertices {
#     x: 1221
#     y: 2311
#   }
#   vertices {
#     x: 1113
#     y: 2310
#   }
# }
# , description: "(3)"
# bounding_poly {
#   vertices {
#     x: 322
#     y: 2328
#   }
#   vertices {
#     x: 360
#     y: 2328
#   }
#   vertices {
#     x: 360
#     y: 2358
#   }
#   vertices {
#     x: 322
#     y: 2358
#   }
# }
# , description: "Od"
# bounding_poly {
#   vertices {
#     x: 381
#     y: 2330
#   }
#   vertices {
#     x: 421
#     y: 2330
#   }
#   vertices {
#     x: 421
#     y: 2355
#   }
#   vertices {
#     x: 381
#     y: 2355
#   }
# }
# , description: "ulo\305\276en\303\255"
# bounding_poly {
#   vertices {
#     x: 447
#     y: 2329
#   }
#   vertices {
#     x: 555
#     y: 2329
#   }
#   vertices {
#     x: 555
#     y: 2355
#   }
#   vertices {
#     x: 447
#     y: 2355
#   }
# }
# , description: "sankce"
# bounding_poly {
#   vertices {
#     x: 579
#     y: 2330
#   }
#   vertices {
#     x: 680
#     y: 2330
#   }
#   vertices {
#     x: 680
#     y: 2355
#   }
#   vertices {
#     x: 579
#     y: 2355
#   }
# }
# , description: "je"
# bounding_poly {
#   vertices {
#     x: 704
#     y: 2329
#   }
#   vertices {
#     x: 730
#     y: 2329
#   }
#   vertices {
#     x: 730
#     y: 2359
#   }
#   vertices {
#     x: 704
#     y: 2359
#   }
# }
# , description: "t\303\251\305\274"
# bounding_poly {
#   vertices {
#     x: 756
#     y: 2329
#   }
#   vertices {
#     x: 799
#     y: 2329
#   }
#   vertices {
#     x: 799
#     y: 2367
#   }
#   vertices {
#     x: 756
#     y: 2367
#   }
# }
# , description: "mo\305\276n\303\251"
# bounding_poly {
#   vertices {
#     x: 824
#     y: 2330
#   }
#   vertices {
#     x: 926
#     y: 2330
#   }
#   vertices {
#     x: 926
#     y: 2356
#   }
#   vertices {
#     x: 824
#     y: 2356
#   }
# }
# , description: "upustit,"
# bounding_poly {
#   vertices {
#     x: 952
#     y: 2336
#   }
#   vertices {
#     x: 1063
#     y: 2336
#   }
#   vertices {
#     x: 1063
#     y: 2362
#   }
#   vertices {
#     x: 952
#     y: 2362
#   }
# }
# , description: "jestli\305\276e"
# bounding_poly {
#   vertices {
#     x: 1086
#     y: 2333
#   }
#   vertices {
#     x: 1190
#     y: 2333
#   }
#   vertices {
#     x: 1190
#     y: 2363
#   }
#   vertices {
#     x: 1086
#     y: 2363
#   }
# }
# , description: "samotne"
# bounding_poly {
#   vertices {
#     x: 1215
#     y: 2327
#   }
#   vertices {
#     x: 1341
#     y: 2327
#   }
#   vertices {
#     x: 1341
#     y: 2355
#   }
#   vertices {
#     x: 1215
#     y: 2355
#   }
# }
# , description: "projedn\303\241nt"
# bounding_poly {
#   vertices {
#     x: 1366
#     y: 2324
#   }
#   vertices {
#     x: 1526
#     y: 2324
#   }
#   vertices {
#     x: 1526
#     y: 2355
#   }
#   vertices {
#     x: 1366
#     y: 2355
#   }
# }
# , description: "disciplin\303\241mino"
# bounding_poly {
#   vertices {
#     x: 1548
#     y: 2324
#   }
#   vertices {
#     x: 1765
#     y: 2324
#   }
#   vertices {
#     x: 1765
#     y: 2353
#   }
#   vertices {
#     x: 1548
#     y: 2353
#   }
# }
# , description: "p\305\231estupku"
# bounding_poly {
#   vertices {
#     x: 381
#     y: 2368
#   }
#   vertices {
#     x: 532
#     y: 2367
#   }
#   vertices {
#     x: 532
#     y: 2398
#   }
#   vertices {
#     x: 381
#     y: 2399
#   }
# }
# , description: "vede"
# bounding_poly {
#   vertices {
#     x: 541
#     y: 2369
#   }
#   vertices {
#     x: 614
#     y: 2368
#   }
#   vertices {
#     x: 614
#     y: 2395
#   }
#   vertices {
#     x: 541
#     y: 2396
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 624
#     y: 2369
#   }
#   vertices {
#     x: 639
#     y: 2369
#   }
#   vertices {
#     x: 639
#     y: 2393
#   }
#   vertices {
#     x: 624
#     y: 2393
#   }
# }
# , description: "n\303\241prav\304\233."
# bounding_poly {
#   vertices {
#     x: 648
#     y: 2360
#   }
#   vertices {
#     x: 774
#     y: 2359
#   }
#   vertices {
#     x: 774
#     y: 2397
#   }
#   vertices {
#     x: 648
#     y: 2398
#   }
# }
# , description: "(4)Ph"
# bounding_poly {
#   vertices {
#     x: 322
#     y: 2424
#   }
#   vertices {
#     x: 416
#     y: 2424
#   }
#   vertices {
#     x: 416
#     y: 2457
#   }
#   vertices {
#     x: 322
#     y: 2457
#   }
# }
# , description: "ukt\303\241d\303\241n\303\255"
# bounding_poly {
#   vertices {
#     x: 429
#     y: 2425
#   }
#   vertices {
#     x: 557
#     y: 2425
#   }
#   vertices {
#     x: 557
#     y: 2453
#   }
#   vertices {
#     x: 429
#     y: 2453
#   }
# }
# , description: "sankci"
# bounding_poly {
#   vertices {
#     x: 568
#     y: 2426
#   }
#   vertices {
#     x: 661
#     y: 2426
#   }
#   vertices {
#     x: 661
#     y: 2454
#   }
#   vertices {
#     x: 568
#     y: 2454
#   }
# }
# , description: "se"
# bounding_poly {
#   vertices {
#     x: 672
#     y: 2433
#   }
#   vertices {
#     x: 704
#     y: 2433
#   }
#   vertices {
#     x: 704
#     y: 2454
#   }
#   vertices {
#     x: 672
#     y: 2454
#   }
# }
# , description: "p\305\231ihlizi"
# bounding_poly {
#   vertices {
#     x: 718
#     y: 2426
#   }
#   vertices {
#     x: 817
#     y: 2426
#   }
#   vertices {
#     x: 817
#     y: 2464
#   }
#   vertices {
#     x: 718
#     y: 2464
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 828
#     y: 2428
#   }
#   vertices {
#     x: 842
#     y: 2428
#   }
#   vertices {
#     x: 842
#     y: 2453
#   }
#   vertices {
#     x: 828
#     y: 2453
#   }
# }
# , description: "charakteru"
# bounding_poly {
#   vertices {
#     x: 855
#     y: 2428
#   }
#   vertices {
#     x: 1015
#     y: 2428
#   }
#   vertices {
#     x: 1015
#     y: 2456
#   }
#   vertices {
#     x: 855
#     y: 2456
#   }
# }
# , description: "jedn\303\241nt,"
# bounding_poly {
#   vertices {
#     x: 1025
#     y: 2430
#   }
#   vertices {
#     x: 1145
#     y: 2430
#   }
#   vertices {
#     x: 1145
#     y: 2461
#   }
#   vertices {
#     x: 1025
#     y: 2461
#   }
# }
# , description: "j\303\241m2"
# bounding_poly {
#   vertices {
#     x: 1154
#     y: 2428
#   }
#   vertices {
#     x: 1217
#     y: 2428
#   }
#   vertices {
#     x: 1217
#     y: 2461
#   }
#   vertices {
#     x: 1154
#     y: 2461
#   }
# }
# , description: "by\305\202"
# bounding_poly {
#   vertices {
#     x: 1230
#     y: 2427
#   }
#   vertices {
#     x: 1274
#     y: 2427
#   }
#   vertices {
#     x: 1274
#     y: 2464
#   }
#   vertices {
#     x: 1230
#     y: 2464
#   }
# }
# , description: "disciplin\303\241m\303\255"
# bounding_poly {
#   vertices {
#     x: 1284
#     y: 2422
#   }
#   vertices {
#     x: 1463
#     y: 2422
#   }
#   vertices {
#     x: 1463
#     y: 2464
#   }
#   vertices {
#     x: 1284
#     y: 2464
#   }
# }
# , description: "p\305\231estupek"
# bounding_poly {
#   vertices {
#     x: 1468
#     y: 2418
#   }
#   vertices {
#     x: 1622
#     y: 2418
#   }
#   vertices {
#     x: 1622
#     y: 2464
#   }
#   vertices {
#     x: 1468
#     y: 2464
#   }
# }
# , description: "spich\303\241n"
# bounding_poly {
#   vertices {
#     x: 1624
#     y: 2418
#   }
#   vertices {
#     x: 1763
#     y: 2418
#   }
#   vertices {
#     x: 1763
#     y: 2464
#   }
#   vertices {
#     x: 1624
#     y: 2464
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 382
#     y: 2467
#   }
#   vertices {
#     x: 395
#     y: 2467
#   }
#   vertices {
#     x: 395
#     y: 2492
#   }
#   vertices {
#     x: 382
#     y: 2492
#   }
# }
# , description: "okolnostem,"
# bounding_poly {
#   vertices {
#     x: 404
#     y: 2466
#   }
#   vertices {
#     x: 589
#     y: 2465
#   }
#   vertices {
#     x: 589
#     y: 2497
#   }
#   vertices {
#     x: 404
#     y: 2498
#   }
# }
# , description: "za"
# bounding_poly {
#   vertices {
#     x: 604
#     y: 2473
#   }
#   vertices {
#     x: 637
#     y: 2473
#   }
#   vertices {
#     x: 637
#     y: 2494
#   }
#   vertices {
#     x: 604
#     y: 2494
#   }
# }
# , description: "nich\305\276"
# bounding_poly {
#   vertices {
#     x: 654
#     y: 2465
#   }
#   vertices {
#     x: 731
#     y: 2465
#   }
#   vertices {
#     x: 731
#     y: 2493
#   }
#   vertices {
#     x: 654
#     y: 2493
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 749
#     y: 2466
#   }
#   vertices {
#     x: 763
#     y: 2466
#   }
#   vertices {
#     x: 763
#     y: 2492
#   }
#   vertices {
#     x: 749
#     y: 2492
#   }
# }
# , description: "n\304\233mu"
# bounding_poly {
#   vertices {
#     x: 780
#     y: 2465
#   }
#   vertices {
#     x: 865
#     y: 2465
#   }
#   vertices {
#     x: 865
#     y: 2493
#   }
#   vertices {
#     x: 780
#     y: 2493
#   }
# }
# , description: "do\305\241lo,"
# bounding_poly {
#   vertices {
#     x: 882
#     y: 2466
#   }
#   vertices {
#     x: 970
#     y: 2466
#   }
#   vertices {
#     x: 970
#     y: 2498
#   }
#   vertices {
#     x: 882
#     y: 2498
#   }
# }
# , description: "ke"
# bounding_poly {
#   vertices {
#     x: 987
#     y: 2469
#   }
#   vertices {
#     x: 1020
#     y: 2469
#   }
#   vertices {
#     x: 1020
#     y: 2495
#   }
#   vertices {
#     x: 987
#     y: 2495
#   }
# }
# , description: "zp\305\257sobenym"
# bounding_poly {
#   vertices {
#     x: 1027
#     y: 2460
#   }
#   vertices {
#     x: 1229
#     y: 2459
#   }
#   vertices {
#     x: 1229
#     y: 2499
#   }
#   vertices {
#     x: 1027
#     y: 2500
#   }
# }
# , description: "n\303\241sledk\305\257m,"
# bounding_poly {
#   vertices {
#     x: 1246
#     y: 2459
#   }
#   vertices {
#     x: 1414
#     y: 2458
#   }
#   vertices {
#     x: 1414
#     y: 2493
#   }
#   vertices {
#     x: 1246
#     y: 2494
#   }
# }
# , description: "k"
# bounding_poly {
#   vertices {
#     x: 1431
#     y: 2464
#   }
#   vertices {
#     x: 1444
#     y: 2464
#   }
#   vertices {
#     x: 1444
#     y: 2487
#   }
#   vertices {
#     x: 1431
#     y: 2487
#   }
# }
# , description: "mite"
# bounding_poly {
#   vertices {
#     x: 1461
#     y: 2462
#   }
#   vertices {
#     x: 1527
#     y: 2462
#   }
#   vertices {
#     x: 1527
#     y: 2489
#   }
#   vertices {
#     x: 1461
#     y: 2489
#   }
# }
# , description: "zavinent"
# bounding_poly {
#   vertices {
#     x: 1544
#     y: 2461
#   }
#   vertices {
#     x: 1673
#     y: 2460
#   }
#   vertices {
#     x: 1673
#     y: 2493
#   }
#   vertices {
#     x: 1544
#     y: 2494
#   }
# }
# , description: "jako"
# bounding_poly {
#   vertices {
#     x: 1687
#     y: 2464
#   }
#   vertices {
#     x: 1764
#     y: 2464
#   }
#   vertices {
#     x: 1764
#     y: 2494
#   }
#   vertices {
#     x: 1687
#     y: 2494
#   }
# }
# ]

# %% [markdown]
# #### Bonus k první části
# Jak je vidět, výsledky po aplikaci OCR nejsou zcela uspokojivé. Je však v nutné brát potaz, že vstupní obraz není kromě geometrické transformace nijak dále předzpracován. Vzpomeňte si na cvičení, kde jsme aplikovali OCR s knihovnou Tesseract. Tam byly poměrně přísné nároky na vstupní obraz, který musel být perfektně předzpracovaný a v binární podobě. Tesseract je citlivý i na drobné natočení nebo deformování textu. Řešení od Google je v tomto ohledu značně robustnější.
#
# **8) Pokuste se vstupní obraz před aplikací OCR kvalitněji předzpracovat pomocí probíraných technik - crop, segmentace, zaostření, rozmazání, jas, kontrast, apod. Fantazii se meze nekladou. Stručně diskutujte poznatky a vlivy jednotlivých operací na výslednou kvalitu. <span style="color:blue">(0.5 bodu)</span>**
#
# **9) Využijte Google Cloud Translate API k přeložení výsledného textu do angličtiny, výsledek zobrazte a uložte do textového souboru. <span style="color:blue">(0.5 bodu)</span>**

# %% [markdown]
# ### Druhá část - výtvarné umění na FITu
# Práce probíhá s fotografií `fit_budova.jpg` od autora Tomáše Kouby a s malbou `fit_logo.jpg` od autora Lukáš Brchla. Cílem je umístit obrázek loga na stěnu budovy FITu viz obrázek. Za tuto část je možné získat maximálně **3 body** a **až 1 prémiový**.
#
# ![](fit_logo_merged.jpg)

# %% [markdown]
# **1) Načtěte obrázky a vytvořte pole korespondečních souřadnic rohů malby.**

# %%
main_img = cv2.imread('fit_budova.jpg')
logo_img = cv2.imread('fit_logo.jpg')
logo_pts = np.array(select_image_points(logo_img))
print('format: x, y \n', logo_pts)
# Out:
# format: x, y
#  [[  1   4]
#  [137   5]
#  [138 713]
#  [  0 712]]

# %% [markdown]
# **2) Vyberte souřadnice v obraze, do kterých má být logo transformováno (pozor na pořadí).**

# %%
image_pts = np.array(select_image_points(main_img))
if (len(image_pts) != len(logo_pts)):
    raise ValueError('Real world points and image points must be the same size.')

print('format: x, y \n', image_pts)
# Out:
# format: x, y
#  [[189  24]
#  [250  65]
#  [173 410]
#  [ 70 414]]

# %% [markdown]
# **3) Vypočtěte transformační matici H, vypište její tvar.**

# %%
H, mask = cv2.findHomography(logo_pts, image_pts)
print(H)
# Out:
# [[0.683 -0.197 188.960]
#  [0.359 0.374 22.127]
#  [0.001 -0.000 1.000]]

# %% [markdown]
# **4) Využijte funkci `cv2.warpPerspective()` k vytvoření stejné perspektivy loga jako fotografie budovy. Zobrazte výsledky.**

# %%
image_warped = cv2.warpPerspective(logo_img, H, (len(main_img[0]), len(main_img)))
show_images(image_warped)

# %% [markdown]
# **5) Logo je nutné umístit na budovu bez bílého pozadí, je tedy nutné ho segmentovat.**
#
# Tady se mohou vaše postupy lišit. Kvalita segmentace následně razantně rozhoduje o kvalitě výsledku. Zkuste experimentovat s různými druhy segmentace a zkuste využít i nějaké funkce pro předzpracování, jako např. rozmazání. Může se vám hodit funkce `cv2.bitwise_and`.

# %%
ref_mask = cv2.inRange(image_warped, (0, 0, 0), (250, 200, 30))
res = cv2.bitwise_and(image_warped, image_warped, mask=ref_mask)
show_images(res)

# %% [markdown]
# **6) Spojte zdrojovou fotografii budovy se segmentovaným logem. Výsledek zobrazte a uložte.**
#
# Nejedná se o žádnou složitou operaci, existuje na to přímo OpenCV funkce.

# %%
vis = cv2.add(res, main_img)
show_images(vis)

# %% [markdown]
# #### Bonus k druhé části
# **7) Vymyslete a naprogramujte další využití perspektivní transformace pro nadcházející studenty BI-SVZ. Pro získání nápadu se lze odpíchnout od témat spojování snímků (panorama), rozšířené reality a 3D rekonstrukce. Pokud vůbec netušíte, hledejte v Google images klíčová slova "homography" nebo "perspective transform". Znovu podotýkám, že fantazii se meze nekladou a nebojte se případné dotazy/nápady konzultovat přímo s námi! <span style="color:blue">(1 bod)</span>**
