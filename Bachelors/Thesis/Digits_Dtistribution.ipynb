# %% [markdown]
# ## Digits distribution

# %% [markdown]
# Notebook used for digits distribution experiments. Only report cells are able to run due to missing data.

# %%
from utils import *

# %%
DATA_AVAILABLE = False

# %%
if DATA_AVAILABLE:
    charged_off = pd.read_csv('data\\Charged_Off_Reduced.csv', index_col = 0)
    marked_frauds = pd.read_csv('data\\Frauds_Reduced.csv', index_col = 0)

# %%
if DATA_AVAILABLE:
    charged_off_dist = charged_off.apply(lambda row: digit_dist(row), axis=1, result_type='expand')
    charged_off_dist['fraud'] = charged_off['fraud']
    marked_frauds_dist = marked_frauds.apply(lambda row: digit_dist(row), axis=1, result_type='expand')
    marked_frauds_dist['fraud'] = marked_frauds['fraud']

# %%
if DATA_AVAILABLE:
    charged_off_dist.to_csv('data/charged_off_dist.csv')
    marked_frauds_dist.to_csv('data/marked_dist.csv')

# %%
strategies = []

# %%
if DATA_AVAILABLE:
    df = stratified_k_fold(charged_off_dist, strategies, 'Transformations - Charged off', verbose=False)
    df.to_csv('experiments/Digits_Distribution/A.csv')

# %%
get_report(pd.read_csv('experiments/Digits_Distribution/A.csv', index_col=0).fillna(0))
# Out:
# Overall results (mean):
#                                                         f1  precision  recall
# preprocessor classifier
# 0.0          DecisionTreeClassifier(random_state=12)  0.13       0.08    0.36
#              LogisticRegression(random_state=12)      0.22       0.64    0.22
#              MLPClassifier(random_state=12)           0.22       0.64    0.26
#              RandomForestClassifier(random_state=12)  0.21       0.58    0.25
#              SVC(random_state=12)                     0.24       0.78    0.18
# Overall results (max):
#                                                         f1  precision  recall
# preprocessor classifier
# 0.0          DecisionTreeClassifier(random_state=12)  0.16       0.13    0.54
#              LogisticRegression(random_state=12)      0.26       0.98    0.42
#              MLPClassifier(random_state=12)           0.26       0.98    0.60
#              RandomForestClassifier(random_state=12)  0.26       0.98    0.52
# ...

# %%
if DATA_AVAILABLE:
    df = stratified_k_fold(marked_frauds_dist, strategies, 'Transformations - Charged off', verbose=False, f_type='marked')
    df.to_csv('experiments/Digits_Distribution/B.csv')

# %%
get_report(pd.read_csv('experiments/Digits_Distribution/B.csv', index_col = 0).fillna(0))
# Out:
# Overall results (mean):
#                                                         f1  precision  recall
# preprocessor classifier
# 0.0          DecisionTreeClassifier(random_state=12)  0.01       0.01    0.21
#              LogisticRegression(random_state=12)      0.01       0.00    0.10
#              MLPClassifier(random_state=12)           0.01       0.01    0.01
#              RandomForestClassifier(random_state=12)  0.01       0.00    0.12
#              SVC(random_state=12)                     0.00       0.00    0.12
# Overall results (max):
#                                                         f1  precision  recall
# preprocessor classifier
# 0.0          DecisionTreeClassifier(random_state=12)  0.02       0.01    0.54
#              LogisticRegression(random_state=12)      0.02       0.01    0.50
#              MLPClassifier(random_state=12)           0.03       0.02    0.04
#              RandomForestClassifier(random_state=12)  0.02       0.01    0.54
# ...

# %% [markdown]
# ## Model tuning for dataset A

# %%
if DATA_AVAILABLE:
    X, y = split(charged_off_dist)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12, stratify=y)

# %%
clf_r_forrest = RandomForestClassifier(random_state=12, bootstrap=True, criterion='gini', max_depth=10, max_features='sqrt', n_estimators=10)
p = Pipeline(steps=[('f', clf_r_forrest)])
if DATA_AVAILABLE:
    t = tune_params(p, forest_grid , 0.05, X_train, y_train, 'results/Digits_Distribution/RF_5.csv', n_iter=100)
else:
    display(pd.read_csv('results/Digits_Distribution/RF_5.csv').sort_values('f1', ascending=False).head(1))
# Out:
#     Unnamed: 0  Unnamed: 0.1  f__bootstrap f__class_weight f__criterion  \
# 93          93            93          True             NaN         gini
#
#     f__max_depth f__max_features  f__min_samples_leaf  f__min_samples_split  \
# 93          10.0            sqrt                    1                     2
#
#     f__n_estimators  prec        f1    recall
# 93               10  0.94  0.261268  0.153109

# %%
if DATA_AVAILABLE:
    test_model(X_train, X_test, y_train, y_test, p, 0.05)
# Out:
# F1 score: 0.26
# Precision score: 0.94
# Recall score: 0.15
